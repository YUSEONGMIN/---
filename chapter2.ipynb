# %% [markdown]
# # 분류

# %% [markdown]
# # 서비스 이탈 예측 데이터

# %%
# 고객의 신상정보 데이터를 통한 회사 서비스 이탈 예측 (종속변수 : Exited)
dataurl1 = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv'
dataurl2 = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv'
dataurl3 = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv'
dataurl4 = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv'

# %%
import pandas as pd
x_train = pd.read_csv(dataurl1)
y_train = pd.read_csv(dataurl2)
x_test = pd.read_csv(dataurl3)

# %%
# x_train.info()
# y_train.info()
# x_test.info()

# %%
drop_col = ['CustomerId','Surname']
x_train_drop = x_train.drop(columns = drop_col)
x_test_drop = x_test.drop(columns = drop_col)

# %%
# !pip install scikit-learn
